# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mdtraj as md
import seaborn as sns
import matplotlib as mpl
#%matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
sns.set(style='white')
from pylab import *

# %%
## read temp and change column first
ff = pd.read_csv('../../WT/data/SimContactFrequency.PROC.csv')
ff['Avg']=ff.mean(axis=1)
ff ['RESNAME'] = ff.iloc[:,0]
ff= ff [['RESNAME','Sim1','Sim2','Sim3','Sim4','Avg']]
ff.to_csv('modified.PROC.WT.csv', index=False)

## assign row for PROC read data and save csv file
#col_list = ["RESNAME","Sim1","Sim2","Sim3","Sim4"]
col_list = ["RESNAME","Avg"]
#df = pd.read_csv("SimCA_ZDistvsRes.PROC.csv", usecols=col_list,index_col=0 )
ff = pd.read_csv("modified.PROC.WT.csv", usecols=col_list,index_col=0 )
cl_list = ["RESNAME"]
ff1 = pd.read_csv('GluN1.csv',usecols=cl_list)
ff.index = ff.reindex(ff1.RESNAME).index
ff.to_csv('SimContactFreq.PROC.WT.Avg.csv')
#####################################################################

fd = pd.read_csv('../../WT/data/SimContactFrequency.PROG.csv')
fd['Avg']=fd.mean(axis=1)
fd ['RESNAME'] = fd.iloc[:,0]
fd= fd [['RESNAME','Sim1','Sim2','Sim3','Sim4','Avg']]

fd.to_csv('modified.PROG.WT.csv', index=False)

## assign row for PROC read data and save csv file
col_list = ["RESNAME","Avg"]
#df = pd.read_csv("SimCA_ZDistvsRes.PROC.csv", usecols=col_list,index_col=0 )
fd = pd.read_csv("modified.PROG.WT.csv", usecols=col_list,index_col=0 )
cl_list = ["RESNAME"]
fd1 = pd.read_csv('GluN1.csv',usecols=cl_list)
fd.index = fd.reindex(fd1.RESNAME).index
fd.to_csv('SimContactFreq.PROG.WT.Avg.csv')


PROCA = pd.read_csv('SimContactFreq.PROC.WT.Avg.csv', index_col=0, skiprows=65, names=["Avg"])
PROGE = pd.read_csv('SimContactFreq.PROG.WT.Avg.csv', index_col=0, skiprows=65, names=["Avg"])

PROCA["Avg"] = (PROCA['Avg']+PROGE['Avg'])/2

##############################################################################
##############################################################################

## read temp and change column first
df = pd.read_csv('../../Mu1/data/SimContactFrequency.PROC.csv')
df['Avg']=df.mean(axis=1)
df ['RESNAME'] = df.iloc[:,0]
df= df [['RESNAME','Sim1','Sim2','Sim3','Sim4','Avg']]
df.to_csv('modified.PROC.Mu1.csv', index=False)

## assign row for PROC read data and save csv file
#col_list = ["RESNAME","Sim1","Sim2","Sim3","Sim4"]
col_list = ["RESNAME","Avg"]
#df = pd.read_csv("SimCA_ZDistvsRes.PROC.csv", usecols=col_list,index_col=0 )
df = pd.read_csv("modified.PROC.Mu1.csv", usecols=col_list,index_col=0 )
cl_list = ["RESNAME"]
df1 = pd.read_csv('GluN1.csv',usecols=cl_list)
df.index = df.reindex(df1.RESNAME).index
df.to_csv('SimContactFreq.PROC.Mu1.Avg.csv')
#####################################################################

dd = pd.read_csv('../../Mu1/data/SimContactFrequency.PROG.csv')
dd['Avg']=dd.mean(axis=1)
dd ['RESNAME'] = dd.iloc[:,0]
dd= dd [['RESNAME','Sim1','Sim2','Sim3','Sim4','Avg']]
dd.to_csv('modified.PROG.Mu1.csv', index=False)

## assign row for PROC read data and save csv file
col_list = ["RESNAME","Avg"]
#df = pd.read_csv("SimCA_ZDistvsRes.PROC.csv", usecols=col_list,index_col=0 )
dd = pd.read_csv("modified.PROG.Mu1.csv", usecols=col_list,index_col=0 )
cl_list = ["RESNAME"]
dd1 = pd.read_csv('GluN1.csv',usecols=cl_list)
dd.index = dd.reindex(dd1.RESNAME).index
dd.to_csv('SimContactFreq.PROG.Mu1.Avg.csv')


PROC = pd.read_csv('SimContactFreq.PROC.Mu1.Avg.csv', index_col=0, skiprows=65, names=["Avg"])
PROG = pd.read_csv('SimContactFreq.PROG.Mu1.Avg.csv', index_col=0, skiprows=65, names=["Avg"])

PROC["Avg"] = (PROC['Avg']+PROG['Avg'])/2
###########################################################################################
###########################################################################################

## read temp and change column first
sf = pd.read_csv('../../Mu2/data/SimContactFrequency.PROC.csv')
sf['Avg']=sf.mean(axis=1)
sf ['RESNAME'] = sf.iloc[:,0]
sf= sf [['RESNAME','Sim1','Sim2','Sim3','Sim4','Avg']]
sf.to_csv('modified.PROC.Mu2.csv', index=False)

## assign row for PROC read data and save csv file
#col_list = ["RESNAME","Sim1","Sim2","Sim3","Sim4"]
col_list = ["RESNAME","Avg"]
#df = pd.read_csv("SimCA_ZDistvsRes.PROC.csv", usecols=col_list,index_col=0 )
sf = pd.read_csv("modified.PROC.Mu2.csv", usecols=col_list,index_col=0 )
cl_list = ["RESNAME"]
sf1 = pd.read_csv('GluN1.csv',usecols=cl_list)
sf.index = sf.reindex(sf1.RESNAME).index
sf.to_csv('SimContactFreq.PROC.Mu2.Avg.csv')
#####################################################################

sd = pd.read_csv('../../Mu2/data/SimContactFrequency.PROG.csv')
sd['Avg']=sd.mean(axis=1)
sd ['RESNAME'] =sd.iloc[:,0]
sd= sd [['RESNAME','Sim1','Sim2','Sim3','Sim4','Avg']]
sd.to_csv('modified.PROG.Mu2.csv', index=False)

## assign row for PROC read data and save csv file
col_list = ["RESNAME","Avg"]
#df = pd.read_csv("SimCA_ZDistvsRes.PROC.csv", usecols=col_list,index_col=0 )
sd = pd.read_csv("modified.PROG.Mu2.csv", usecols=col_list,index_col=0 )
cl_list = ["RESNAME"]
sf1 = pd.read_csv('GluN1.csv',usecols=cl_list)
sd.index = sd.reindex(sf1.RESNAME).index
sd.to_csv('SimContactFreq.PROG.Mu2.Avg.csv')


PROCAA = pd.read_csv('SimContactFreq.PROC.Mu2.Avg.csv', index_col=0, skiprows=65, names=["Avg"])
PROGEE = pd.read_csv('SimContactFreq.PROG.Mu2.Avg.csv', index_col=0, skiprows=65, names=["Avg"])


PROCAA["Avg"] = (PROCAA['Avg']+PROGEE['Avg'])/2
###############################################################################
###############################################################################
## read temp and change column first
cf = pd.read_csv('../../Mu3/data/SimContactFrequency.PROC.csv')
cf['Avg']=cf.mean(axis=1)
cf ['RESNAME'] = cf.iloc[:,0]
cf= cf [['RESNAME','Sim1','Sim2','Sim3','Sim4','Avg']]
cf.to_csv('modified.PROC.Mu3.csv', index=False)

## assign row for PROC read data and save csv file
#col_list = ["RESNAME","Sim1","Sim2","Sim3","Sim4"]
col_list = ["RESNAME","Avg"]
#df = pd.read_csv("SimCA_ZDistvsRes.PROC.csv", usecols=col_list,index_col=0 )
cf = pd.read_csv("modified.PROC.Mu3.csv", usecols=col_list,index_col=0 )
cl_list = ["RESNAME"]
cf1 = pd.read_csv('GluN1.csv',usecols=cl_list)
cf.index = cf.reindex(sf1.RESNAME).index
cf.to_csv('SimContactFreq.PROC.Mu3.Avg.csv')
#####################################################################

cd = pd.read_csv('../../Mu3/data/SimContactFrequency.PROG.csv')
cd['Avg']=cd.mean(axis=1)
cd ['RESNAME'] =cd.iloc[:,0]
cd= cd [['RESNAME','Sim1','Sim2','Sim3','Sim4','Avg']]
cd.to_csv('modified.PROG.Mu3.csv', index=False)

## assign row for PROC read data and save csv file
col_list = ["RESNAME","Avg"]
#df = pd.read_csv("SimCA_ZDistvsRes.PROC.csv", usecols=col_list,index_col=0 )
cd = pd.read_csv("modified.PROG.Mu3.csv", usecols=col_list,index_col=0 )
cl_list = ["RESNAME"]
cf1 = pd.read_csv('GluN1.csv',usecols=cl_list)
cd.index = cd.reindex(cf1.RESNAME).index
cd.to_csv('SimContactFreq.PROG.Mu3.Avg.csv')


PROCAAAA = pd.read_csv('SimContactFreq.PROC.Mu3.Avg.csv', index_col=0, skiprows=65, names=["Avg"])
PROGEEEE = pd.read_csv('SimContactFreq.PROG.Mu3.Avg.csv', index_col=0, skiprows=65, names=["Avg"])


PROCAAAA["Avg"] = (PROCAAAA['Avg']+PROGEEEE['Avg'])/2
###########################################################################################################
###########################################################################################################

# %%
sns.set_style("whitegrid")
fig1, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(15,6), sharex=True, num=12592)
cbax = fig1.add_axes([0.91, 0.125, 0.025, 0.755])
fig1.subplots_adjust(hspace=0.025, wspace = 0)
res = sns.heatmap(PROCA.T, cmap='BuPu', annot=True, annot_kws={'fontsize':10, 'rotation':'vertical'},fmt='.2f', ax=ax1, cbar_ax=cbax, vmin=0, vmax=0.9)
res1 = sns.heatmap(PROC.T, cmap='BuPu', annot=True, annot_kws={'fontsize':10, 'rotation':'vertical'},fmt='.2f', ax=ax2, cbar_ax=cbax,vmin=0, vmax=0.9)
res2 = sns.heatmap(PROCAA.T, cmap='BuPu', annot=True, annot_kws={'fontsize':10, 'rotation':'vertical'},fmt='.2f', ax=ax3, cbar_ax=cbax,vmin=0, vmax=0.9)
res3 = sns.heatmap(PROCAAAA.T, cmap='BuPu', annot=True, annot_kws={'fontsize':10, 'rotation':'vertical'},
           fmt='.2f', ax=ax4, cbar_ax=cbax, vmin=0, vmax=0.9)

# make frame visible
for _, spine in res.spines.items():
    spine.set_visible(True)

for _, spine in res1.spines.items():
    spine.set_visible(True)

for _, spine in res2.spines.items():
    spine.set_visible(True)

for _, spine in res3.spines.items():
    spine.set_visible(True)

#sns.heatmap(TrajHBCountDFm.T, linecolor='white',cmap='rainbow', annot=False, annot_kws={'fontsize':13, 'rotation':'vertical','weight':'bold'},
#            fmt='.2f', ax=ax1, cbar_ax=cbax1)
ax2.set_xlabel('RESNAME', weight='bold', fontsize=16)
ax1.set_ylabel('V637', weight='bold', fontsize=10)
ax2.set_ylabel('V637', weight='bold', fontsize=10)
ax3.set_ylabel('V637', weight='bold', fontsize=10)
ax4.set_ylabel('I637', weight='bold', fontsize=10)

ax1.set_title('GluN1 subunits:Avg', weight='bold', fontsize=16)
ax4.tick_params(axis='both', which= 'major',bottom = 1, left=1, labelsize=12, length=5, width=1 )
ax3.tick_params(axis='y', which= 'major',bottom = 1, left=1, labelsize=12, length=5, width=1 )
ax1.tick_params(axis='y', which= 'major',bottom = 1, left=1, labelsize=12, length=5, width=1 )
ax2.tick_params(axis='y', which= 'major',bottom = 1, left=1, labelsize=12, length=5, width=1 )

#ax1.vlines(46, ymin=0, ymax=1, linestyle='--', color='goldenrod', linewidth=2)
#ax1.vlines(50, ymin=0, ymax=1, linestyle='--', color='goldenrod', linewidth=2)

ax4.text(7, 0.05, 'M2 top', fontsize=12, color='black', va='top' )
ax4.text(50, 0.05, 'M3', fontsize=12, color='black', va='top')

ax1.text(60, 0.1, 'WT', fontsize=12, color='black', va='top')
ax2.text(60, 0.1, 'M639I:AC', fontsize=12, color='black', va='top')
ax3.text(60, 0.1, 'M639L:AC', fontsize=12, color='black', va='top')
ax4.text(60, 0.1, 'V637I:BD', fontsize=12, color='black', va='top')

ax4.text(43, 0.2, '+2', fontsize=10, color='black', va='top')
ax4.text(47, 0.2, '+6', fontsize=10, color='black', va='top')
ax4.text(51, 0.2, '+10', fontsize=10, color='black', va='top')



# make frame visible

#ax1.set_xlim([174, 274])
#ax1.tick_params(labelsize=15)
cbax.tick_params(labelsize=16)
cbax.set_ylabel(r'$\mathbf{Contact \ \ Frequency}$',fontsize=16,weight='bold')
#cbax1.set_ylim(0.0,0.6)
#fig1.savefig('HB_freq.Heatmap.GluN1.Mu1.Mu2.Mu3.WT.PROC.PROG.Avg.last100ns.png',
#             bbox_inches='tight', dpi=600)
# Out:
# Text(1445.625, 0.5, '$\\mathbf{Contact \\ \\ Frequency}$')
